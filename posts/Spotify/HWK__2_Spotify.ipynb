# %% [markdown]
# ---
# title: Spotify Analysis
# author: Cailtin Roos
# date: 2025-03-02
# categories: [python, analysis, spotify] # tags for a blog post (e.g., python)
# image: "spotify.png"
#
# toc: true
# ---

# %% [markdown]
# # Lets examine the Spotify data frame.

# %%
import pandas as pd
spotify = pd.read_csv('https://bcdanl.github.io/data/spotify_all.csv')
spotify
# Out:
#            pid playlist_name  pos        artist_name  \
# 0            0    Throwbacks    0      Missy Elliott
# 1            0    Throwbacks    1     Britney Spears
# 2            0    Throwbacks    2            Beyoncé
# 3            0    Throwbacks    3  Justin Timberlake
# 4            0    Throwbacks    4             Shaggy
# ...        ...           ...  ...                ...
# 198000  999998            ✝️    6       Chris Tomlin
# 198001  999998            ✝️    7       Chris Tomlin
# 198002  999998            ✝️    8            Crowder
# 198003  999998            ✝️    9       Chris Tomlin
# 198004  999998            ✝️   10   Caleb and Kelsey
#
#                                         track_name  duration_ms  \
# 0       Lose Control (feat. Ciara & Fat Man Scoop)       226863
# 1                                            Toxic       198800
# 2                                    Crazy In Love       235933
# 3                                   Rock Your Body       267266
# 4                                     It Wasn't Me       227600
# ...                                            ...          ...
# 198000                                   Waterfall       209573
# 198001                                    The Roar       220106
# 198002        Lift Your Head Weary Sinner (Chains)       224666
# 198003                                We Fall Down       280960
# 198004      10,000 Reasons / What a Beautiful Name       178189
#
#                                             album_name
# 0                                         The Cookbook
# 1                                          In The Zone
# 2         Dangerously In Love (Alben für die Ewigkeit)
# 3                                            Justified
# 4                                             Hot Shot
# ...                                                ...
# 198000                                    Love Ran Red
# 198001                                    Love Ran Red
# 198002                                    Neon Steeple
# 198003  How Great Is Our God: The Essential Collection
# 198004          10,000 Reasons / What a Beautiful Name
#
# [198005 rows x 7 columns]

# %% [markdown]
# ### My favorite artist is Miranda Lambert, lets see which of her songs are in this dataframe.

# %%
_mir = (
    spotify[spotify['artist_name']=='Miranda Lambert'] #sort out my FAV artist
    .drop_duplicates(subset=['track_name']) # list each track only once, as it may be in multiple playlists
    )

_mir[["artist_name", 'track_name']] # list only artist name and track, rest is gibberish
# Out:
#             artist_name                                      track_name
# 2691    Miranda Lambert                             Mama's Broken Heart
# 2820    Miranda Lambert                                      White Liar
# 3153    Miranda Lambert    Somethin' Bad - (Duet with Carrie Underwood)
# 3154    Miranda Lambert                                Gunpowder & Lead
# 3155    Miranda Lambert                         The House That Built Me
# 3156    Miranda Lambert                                Little Red Wagon
# 3158    Miranda Lambert                                   Only Prettier
# 3159    Miranda Lambert                                 Heart Like Mine
# 3679    Miranda Lambert                            Fastest Girl in Town
# 23681   Miranda Lambert                                         Tin Man
# 23725   Miranda Lambert                                        Over You
# 24102   Miranda Lambert  Smokin' and Drinkin' - [feat. Little Big Town]
# 24104   Miranda Lambert                                       Automatic
# 24106   Miranda Lambert                      Baggage Claim - Radio Edit
# 24115   Miranda Lambert                                            Vice
# 26837   Miranda Lambert                                 Sweet By and By
# 59168   Miranda Lambert                          Me and Your Cigarettes
# 65727   Miranda Lambert                              All Kinds of Kinds
# 78348   Miranda Lambert                            We Should Be Friends
# 104090  Miranda Lambert                                        Kerosene
# 104227  Miranda Lambert                                   More Like Her
# 136779  Miranda Lambert                             Crazy Ex-Girlfriend
# 141663  Miranda Lambert                               Maintain the Pain
# 193214  Miranda Lambert                                       Love Song

# %% [markdown]
# ### Lets see what song in the Spotify dateframe has the longest runtime.

# %%
spotify.sort_values('duration_ms', ascending= False)[:1]
# Out:
#            pid playlist_name  pos     artist_name  \
# 196517  999977    Audiobooks    6  DBS Audiobooks
#
#                                                track_name  duration_ms  \
# 196517  The Hound of the Baskervilles - Sir Arthur Con...     20744575
#
#                                                album_name
# 196517  The Hound of the Baskervilles - Sir Arthur Con...

# %% [markdown]
# ### Lets see what the average length of one of Miranda Lamberts songs is.

# %%
ave = _mir['duration_ms'].mean().round()
ave
# Out:
# 210422.0

# %% [markdown]
# ### Lets see how many songs by Miranda Lambert have a shorter runtime than the average we found above

# %%
_mir.query(f"duration_ms < {ave}")
# Out:
#            pid playlist_name  pos      artist_name  \
# 2691        44  taylor swift   12  Miranda Lambert
# 3153        55     Tennessee   28  Miranda Lambert
# 3154        55     Tennessee   29  Miranda Lambert
# 3156        55     Tennessee   31  Miranda Lambert
# 3158        55     Tennessee   33  Miranda Lambert
# 3159        55     Tennessee   34  Miranda Lambert
# 3679        64     Elizabeth   41  Miranda Lambert
# 24106      378       country   59  Miranda Lambert
# 59168      879       Country   10  Miranda Lambert
# 78348     1161  country favs   51  Miranda Lambert
# 104090    1558  Good Country    8  Miranda Lambert
# 104227    1558  Good Country  145  Miranda Lambert
# 136779  999037          hick   39  Miranda Lambert
# 141663  999115         Dixie   43  Miranda Lambert
# 193214  999915          Sexy   49  Miranda Lambert
#
#                                           track_name  duration_ms  \
# 2691                             Mama's Broken Heart       177773
# 3153    Somethin' Bad - (Duet with Carrie Underwood)       169586
# 3154                                Gunpowder & Lead       191693
# 3156                                Little Red Wagon       204386
# 3158                                   Only Prettier       189440
# 3159                                 Heart Like Mine       177866
# 3679                            Fastest Girl in Town       197600
# 24106                     Baggage Claim - Radio Edit       197546
# 59168                         Me and Your Cigarettes       144133
# 78348                           We Should Be Friends       170746
# 104090                                      Kerosene       185800
# 104227                                 More Like Her       208866
# 136779                           Crazy Ex-Girlfriend       187573
# 141663                             Maintain the Pain       137533
# 193214                                     Love Song       169866
#
#                        album_name
# 2691              Four The Record
# 3153                     Platinum
# 3154          Crazy Ex-Girlfriend
# 3156                     Platinum
# 3158                   Revolution
# 3159                   Revolution
# 3679              Four The Record
# 24106             Four The Record
# 59168                  Revolution
# 78348   The Weight of These Wings
# 104090                   Kerosene
# 104227        Crazy Ex-Girlfriend
# 136779        Crazy Ex-Girlfriend
# 141663                 Revolution
# 193214                 Revolution
